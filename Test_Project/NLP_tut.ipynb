# %%
import os
import nltk
import nltk.corpus

# %%
from nltk.tokenize import word_tokenize

# %%
black_friday = """Laptops are a staple of Black Friday sales; Chromebooks will likely get nice discounts as well.

As for other great deals, PS4 Pro, Xbox One X, and Nintendo Switch bundles seem like a safe bet for discounts, and controllers are often primed for a sale this time of year. VR headsets might get an extra boost on Black Friday, too.

Of course, TVs will be a massive draw; BlackFriday.com expects that the bottom dollar television will be a 32-inch 720p off-brand for as low as $50.

Top smartphones don't typically get actual discounts on Black Friday. More common are 2-for-1 offers or big box stores offering gift cards alongside purchases of popular devices like new iPhones and Samsung Galaxy phones. The same goes for most Apple products, unless we're talking older products. Last year, Apple offered $50 in gift cards for Black Friday Apple.com purchases.
"""

# %%
BF_tokens = word_tokenize(black_friday)

# %%
tagged = nltk.pos_tag(BF_tokens)

# %%
tagged[0:]
# Out:
# [('Laptops', 'NNS'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('staple', 'NN'),
#  ('of', 'IN'),
#  ('Black', 'NNP'),
#  ('Friday', 'NNP'),
#  ('sales', 'NNS'),
#  (';', ':'),
#  ('Chromebooks', 'NNP'),
#  ('will', 'MD'),
#  ('likely', 'RB'),
#  ('get', 'VB'),
#  ('nice', 'JJ'),
#  ('discounts', 'NNS'),
#  ('as', 'IN'),
#  ('well', 'RB'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('for', 'IN'),
#  ('other', 'JJ'),
#  ('great', 'JJ'),
#  ('deals', 'NNS'),
#  (',', ','),
#  ('PS4', 'NNP'),
#  ('Pro', 'NNP'),
#  (',', ','),
#  ('Xbox', 'NNP'),
#  ('One', 'NNP'),
#  ('X', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Nintendo', 'NNP'),
#  ('Switch', 'NNP'),
#  ('bundles', 'VBZ'),
#  ('seem', 'VBP'),
#  ('like', 'IN'),
#  ('a', 'DT'),
#  ('safe', 'JJ'),
#  ('bet', 'NN'),
#  ('for', 'IN'),
#  ('discounts', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('controllers', 'NNS'),
#  ('are', 'VBP'),
#  ('often', 'RB'),
#  ('primed', 'VBN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('sale', 'NN'),
#  ('this', 'DT'),
#  ('time', 'NN'),
#  ('of', 'IN'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('VR', 'NNP'),
#  ('headsets', 'NNS'),
#  ('might', 'MD'),
#  ('get', 'VB'),
#  ('an', 'DT'),
#  ('extra', 'JJ'),
#  ('boost', 'NN'),
#  ('on', 'IN'),
#  ('Black', 'NNP'),
#  ('Friday', 'NNP'),
#  (',', ','),
#  ('too', 'RB'),
#  ('.', '.'),
#  ('Of', 'IN'),
#  ('course', 'NN'),
#  (',', ','),
#  ('TVs', 'NNP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('massive', 'JJ'),
#  ('draw', 'NN'),
#  (';', ':'),
#  ('BlackFriday.com', 'NNP'),
#  ('expects', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('bottom', 'JJ'),
#  ('dollar', 'NN'),
#  ('television', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('32-inch', 'JJ'),
#  ('720p', 'CD'),
#  ('off-brand', 'NN'),
#  ('for', 'IN'),
#  ('as', 'RB'),
#  ('low', 'JJ'),
#  ('as', 'IN'),
#  ('$', '$'),
#  ('50', 'CD'),
#  ('.', '.'),
#  ('Top', 'JJ'),
#  ('smartphones', 'NNS'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('typically', 'RB'),
#  ('get', 'VB'),
#  ('actual', 'JJ'),
#  ('discounts', 'NNS'),
#  ('on', 'IN'),
#  ('Black', 'NNP'),
#  ('Friday', 'NNP'),
#  ('.', '.'),
#  ('More', 'JJR'),
#  ('common', 'JJ'),
#  ('are', 'VBP'),
#  ('2-for-1', 'JJ'),
#  ('offers', 'NNS'),
#  ('or', 'CC'),
#  ('big', 'JJ'),
#  ('box', 'NN'),
#  ('stores', 'NNS'),
#  ('offering', 'VBG'),
#  ('gift', 'NN'),
#  ('cards', 'NNS'),
#  ('alongside', 'VBP'),
#  ('purchases', 'NNS'),
#  ('of', 'IN'),
#  ('popular', 'JJ'),
#  ('devices', 'NNS'),
#  ('like', 'IN'),
#  ('new', 'JJ'),
#  ('iPhones', 'NNS'),
#  ('and', 'CC'),
#  ('Samsung', 'NNP'),
#  ('Galaxy', 'NNP'),
#  ('phones', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('same', 'JJ'),
#  ('goes', 'VBZ'),
#  ('for', 'IN'),
#  ('most', 'JJS'),
#  ('Apple', 'NNP'),
#  ('products', 'NNS'),
#  (',', ','),
#  ('unless', 'IN'),
#  ('we', 'PRP'),
#  ("'re", 'VBP'),
#  ('talking', 'VBG'),
#  ('older', 'JJR'),
#  ('products', 'NNS'),
#  ('.', '.'),
#  ('Last', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('Apple', 'NNP'),
#  ('offered', 'VBD'),
#  ('$', '$'),
#  ('50', 'CD'),
#  ('in', 'IN'),
#  ('gift', 'NN'),
#  ('cards', 'NNS'),
#  ('for', 'IN'),
#  ('Black', 'NNP'),
#  ('Friday', 'NNP'),
#  ('Apple.com', 'NNP'),
#  ('purchases', 'NNS'),
#  ('.', '.')]
